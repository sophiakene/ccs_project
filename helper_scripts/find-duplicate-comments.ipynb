# %%
import pandas as pd

# %%
df = pd.read_csv('../annotations/final_annotations/ALL_annotations.csv', index_col=0)

# %%
df[df.duplicated()]
# Out:
#                                           comment_text  label          party
# 6    Good things come to those who believe, better ...      2        libdems
# 27                                                   👍      2         labour
# 94   I’ve voted Labour my whole voting life. I’m 63...      0         labour
# 129  🔶🟡 Junior Doctors’ Strike:\nRecall Parliament\...      1        libdems
# 145  🔶🟡 Junior Doctors’ Strike:\nRecall Parliament\...      1        libdems
# 161  Not a single normal House Benefits from this s...      0  conservatives
# 187                                    Happy Easter 🐣       2  conservatives
# 197  🔶🟡 Junior Doctors’ Strike:\nRecall Parliament\...      1        libdems
# 198  End of Tories soon…It’s time to finish this ul...      0  conservatives
# 266                                                👍        2         labour
# 268  🟦🟦🟦🟦 🔹\n🟦🟦🟦🟦🟦 🔷\n🔷🔹🔷🔹🔷\n🟦🔹🔷🔷🔹\n🔹🔷🟦🔷🔹🔹🔹\nBLUE W...      1        libdems
# ...
