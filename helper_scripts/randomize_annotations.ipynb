# %%
import pandas as pd

# %%
cons = pd.read_csv("../annotations/sep-jan_conservatives_comments_facepager.csv", index_col=0)
cons["party"] = "conservatives"
cons.rename(columns = {'message':'comment_text'})
labs = pd.read_csv("../annotations/sep-jan_labour_comments_facepager.csv", index_col=0)
labs["party"] = "labour"
labs.rename(columns = {'message':'comment_text'})
libdems = pd.read_csv("../annotations/sep-jan_libdems_comments_facepager.csv", index_col=0)
libdems["party"] = "libdems"
libdems.rename(columns = {'message':'comment_text'})

random_df_with_party = pd.DataFrame(columns=["comment_text", "created_time", "party"])
random_df_without_party = pd.DataFrame(columns=["comment_text", "created_time", "party"])
# Out:
#                                           comment_text  \
# 0    🔶🟡 Shell Profits 🟡 Shell profits increased by ...
# 1    Statement from Richard Foord  Lib Dem MP of Ti...
# 2    Just think, Tory ilk supporters still think th...
# 3    The reality is that any MP who is being invest...
# 4    🔶🟡 Shell Profits 🟡 Shell profits increased by ...
# ..                                                 ...
# 191  PLEASE FOR GOODNESS  SAKE Wake up Britain💥 🇬🇧🇪...
# 192  PLEASE FOR GOODNESS  SAKE Wake up Britain💥 🇬🇧🇪...
# 193  PLEASE FOR GOODNESS  SAKE Wake up Britain💥 🇬🇧🇪...
# 194  You all the same a bunch off well dressed snak...
# 195                                              🇬🇧🇪🇺🌟
#
#                  created_time    party
# 0    2023-02-02T10:39:03+0000  libdems
# 1    2023-02-01T19:54:39+0000  libdems
# 2    2023-01-30T21:28:54+0000  libdems
# 3    2023-01-30T12:51:38+0000  libdems
# 4    2023-02-02T10:39:12+0000  libdems
# ..                        ...      ...
# ...
