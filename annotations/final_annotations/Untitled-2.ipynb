# %%
import re
regex = "\d.*(\d)$"

with open("first_labels.txt", encoding="utf-8") as rf:
    with open("first_labels_real.txt", "w") as wf:
        for line in rf:
            line = line.strip("\n")
            if line:
                label = line[-1]
                if label.isdigit():
                    if int(label) < 3:
                        wf.write(label+"\n")

# %%
len("""1
0
0
2
0
1
0
1
2
0
0
0
0
2
2
1
2
0
0
0
0
2
0
0
1
0
2
0
0
0
2
1
2
1
0
0
0
2
2
0
0""")
# Out:
# 81

# %%
with open("first_labels_real.txt") as f:
    text_array = f.readlines()

# %%
len(text_array)
# Out:
# 71
